# %% [markdown]
# # Traffic detection with custem YOLOv8 models

# %% [markdown]
# ### importing nessesary libraries

# %%
import cv2 # import opencv
from PIL import Image
import os
from ultralytics import YOLO # import the model from ultralytics
import roboflow # to download the dataset

# %% [markdown]
# ## downloading the traffic light dataset from roboflow:
#  https://universe.roboflow.com/sreya-3iisz/traffic-light-detection-ozcos

# %%
rf = Roboflow(api_key="YOUR_API_KEY")

project = rf.workspace("sreya-3iisz").project("traffic-light-detection-ozcos")

dataset = project.version(1).download("yolov8")

# %%
#checking the image size

img_path = "./Traffic-Light-Detection-1/train/images/1_jpg.rf.a7afe1d5339f08cfde15d9055f293ccc.jpg"
img = Image.open(img_path)
img_size = img.size
(img_size)
# Out:
# (640, 640)

# %% [markdown]
# ## Training The YOLOv8 model using a custem dataset

# %%
# inicating the medium pre-trained model

model = YOLO('yolov8m.pt') 

# training the model on custem dataset

retults = model.train(data='data.yaml',epochs=100,imgsz=img_size,device='mps')  ##device - mps for m1/m2/m3
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.11.5 torch-2.2.0 MPS (Apple M3 Max)
# ...

# %% [markdown]
# ## ploting result metrics

# %%
results_graph = Image.open('runs/detect/train/results.png')

results_graph.convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=2400x1200>

# %% [markdown]
# ## Doing Infrence with the BEST model on the Test dataset

# %%
model = YOLO('./runs/detect/train/weights/best.pt')

imgs=['15_jpg.rf.cd5e10f33ae943cfddfe9049ddffe0c5.jpg'
,
'16_jpg.rf.54acc649efb22457c3a8b75ac0a20103.jpg'
,'17_jpg.rf.f37f8a7c826341541a1d247385c4d49d.jpg'
,'21_jpg.rf.a32832967a5cd31f387b22acc274e387.jpg'
,'22_jpg.rf.59bfe5ecdce20b54b92f45ef1501c229.jpg'
,'26_jpg.rf.6396aa0c13ae5578bb6008a70769177e.jpg'
,'28_jpg.rf.a0408e1ed9fee37dd3a54c1afc8d25fd.jpg'
,'35_jpg.rf.40d05e4097256c8b968f89626c955538.jpg'
,'37_jpg.rf.653e7dd6934225f7898fc67c12c178cb.jpg'
,'39_jpg.rf.8f18871f7610a03d3c2f91601e25b8cd.jpg'
,'3_jpg.rf.2be5fe0e3da24eda0c2e5ee7108c6b33.jpg'
,'45_jpg.rf.96ec68e4dda0729fa1fb3a2ad7a05e69.jpg'
,'47_jpg.rf.0b40abc0d1260844d9650c8b9bd42281.jpg'
,'52_jpg.rf.0c41dce60b867b10d92fbb6b43ca0026.jpg'
,'55_jpg.rf.31ac2bab3658d2ef3b62cf71ea77201c.jpg'
,'61_jpg.rf.80a5c2d24a7ad18b1c9a63817a05ac72.jpg'
,'6_jpg.rf.129ef7613a0ea5787bc6e044af188b36.jpg']
      
imgs_path = r'./Traffic-Light-Detection-1/test/images/'

for image_path in imgs:
    
    path = os.path.join(imgs_path,image_path)
    image = Image.open(path)
    results = model.predict(source=image,conf=0.4,save=True)
# Out:
# 0: 640x640 1 Green, 169.0ms
# Speed: 1.6ms preprocess, 169.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
#
# 0: 640x640 1 Red, 149.4ms
# Speed: 0.7ms preprocess, 149.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
#
# 0: 640x640 1 Red, 141.4ms
# Speed: 1.2ms preprocess, 141.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
#
# 0: 640x640 1 Yellow, 131.4ms
# Speed: 0.8ms preprocess, 131.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
#
# 0: 640x640 1 Yellow, 140.7ms
# Speed: 0.8ms preprocess, 140.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
#
# 0: 640x640 1 Green, 145.9ms
# Speed: 0.8ms preprocess, 145.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ...

# %% [markdown]
# ## Testing the model on a webcam

# %%
cap = cv2.VideoCapture(0)  ## capture the source 

while cap.isOpened():
    
    _, frame = cap.read()
    
    results = model.predict(source=frame, show=True, conf=0.4)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
